# %%
import pandas as pd
import numpy as np
import gensim
from gensim import corpora
import pickle
import re
from spacy.lang.en.stop_words import STOP_WORDS
from collections import Counter
from nltk.corpus import wordnet
import nltk
from nltk.tokenize import word_tokenize 
from nltk.stem import WordNetLemmatizer 
# import dask.dataframe as dd
# from dask.multiprocessing import get
import swifter
from tqdm import tqdm

tqdm.pandas()
lemmatizer = WordNetLemmatizer()

# %%
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

# %%
url_pattern = re.compile(r'https?://\S+|www\.\S+')
alpha_pattern = re.compile(r'[^A-Za-z ]+')
def clean_up(x):
    x = url_pattern.sub(r'', x)
    x = alpha_pattern.sub(r'', x)
    word_tokens = word_tokenize(x.lower())
    filtered_sentence =[]
    for w in word_tokens:
        if len(w)<3 or w in STOP_WORDS:
            continue
        filtered_sentence.append(w.lower())
    x = []
    for word in filtered_sentence:
        x.append(lemmatize_words(word))
#         x.append(ps.stem(word))
    x = " ".join(x)
#     x = lemmatize_words(x)
    return x

# %%
df = pd.read_csv("data/drug_review/drugsComTrain_raw.tsv",delimiter="\t")[:11000]
test = pd.read_csv("data/drug_review/drugsComTest_raw.tsv",delimiter="\t")[:4000]
break_point = df.shape[0]

# %%
df.review = df.review.swifter.allow_dask_on_strings().apply((lambda row: clean_up(row)))
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 192, in apply
#     tmp_df = func(sample, *args, **kwds)
#   File "<ipython-input-6-d48a5051b876>", line 1, in <lambda>
#     df.review = df.review.swifter.allow_dask_on_strings().apply((lambda row: clean_up(row)))
#   File "<ipython-input-4-c866fd77829b>", line 4, in clean_up
#     x = url_pattern.sub(r'', x)
# TypeError: expected string or bytes-like object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-d48a5051b876>", line 1, in <module>
#     df.review = df.review.swifter.allow_dask_on_strings().apply((lambda row: clean_up(row)))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 212, in apply
#     return self._dask_apply(func, convert_dtype, *args, **kwds)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 144, in _dask_apply
#     .compute(scheduler=self._scheduler)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\base.py", line 175, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\base.py", line 446, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\multiprocessing.py", line 207, in get
#     **kwargs
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\local.py", line 476, in get_async
#     fire_task()
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\local.py", line 465, in fire_task
#     dumps((dsk[key], data)),
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\multiprocessing.py", line 26, in _dumps
#     return cloudpickle.dumps(x, protocol=pickle.HIGHEST_PROTOCOL)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 1108, in dumps
#     cp.dump(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 473, in dump
#     return Pickler.dump(self, obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 437, in dump
#     self.save(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 638, in save_reduce
#     save(args)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 786, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 786, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 840, in _batch_appends
#     save(x)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 840, in _batch_appends
#     save(x)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 815, in save_list
#     self.memoize(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 460, in memoize
#     self.write(self.put(idx))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 464, in put
#     def put(self, idx):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 2039, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 192, in apply
#     tmp_df = func(sample, *args, **kwds)
#   File "<ipython-input-6-d48a5051b876>", line 1, in <lambda>
#     df.review = df.review.swifter.allow_dask_on_strings().apply((lambda row: clean_up(row)))
#   File "<ipython-input-4-c866fd77829b>", line 4, in clean_up
#     x = url_pattern.sub(r'', x)
# TypeError: expected string or bytes-like object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-d48a5051b876>", line 1, in <module>
#     df.review = df.review.swifter.allow_dask_on_strings().apply((lambda row: clean_up(row)))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 212, in apply
#     return self._dask_apply(func, convert_dtype, *args, **kwds)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 144, in _dask_apply
#     .compute(scheduler=self._scheduler)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\base.py", line 175, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\base.py", line 446, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\multiprocessing.py", line 207, in get
#     **kwargs
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\local.py", line 476, in get_async
#     fire_task()
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\local.py", line 465, in fire_task
#     dumps((dsk[key], data)),
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\multiprocessing.py", line 26, in _dumps
#     return cloudpickle.dumps(x, protocol=pickle.HIGHEST_PROTOCOL)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 1108, in dumps
#     cp.dump(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 473, in dump
#     return Pickler.dump(self, obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 437, in dump
#     self.save(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 638, in save_reduce
#     save(args)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 786, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 786, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 840, in _batch_appends
#     save(x)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 840, in _batch_appends
#     save(x)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 815, in save_list
#     self.memoize(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 460, in memoize
#     self.write(self.put(idx))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 464, in put
#     def put(self, idx):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 2039, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 3342, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 2042, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1385, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1288, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1150, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: can only concatenate str (not "list") to str
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 2039, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 192, in apply
#     tmp_df = func(sample, *args, **kwds)
#   File "<ipython-input-6-d48a5051b876>", line 1, in <lambda>
#     df.review = df.review.swifter.allow_dask_on_strings().apply((lambda row: clean_up(row)))
#   File "<ipython-input-4-c866fd77829b>", line 4, in clean_up
#     x = url_pattern.sub(r'', x)
# TypeError: expected string or bytes-like object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-d48a5051b876>", line 1, in <module>
#     df.review = df.review.swifter.allow_dask_on_strings().apply((lambda row: clean_up(row)))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 212, in apply
#     return self._dask_apply(func, convert_dtype, *args, **kwds)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\swifter\swifter.py", line 144, in _dask_apply
#     .compute(scheduler=self._scheduler)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\base.py", line 175, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\base.py", line 446, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\multiprocessing.py", line 207, in get
#     **kwargs
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\local.py", line 476, in get_async
#     fire_task()
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\local.py", line 465, in fire_task
#     dumps((dsk[key], data)),
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\dask\multiprocessing.py", line 26, in _dumps
#     return cloudpickle.dumps(x, protocol=pickle.HIGHEST_PROTOCOL)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 1108, in dumps
#     cp.dump(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 473, in dump
#     return Pickler.dump(self, obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 437, in dump
#     self.save(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 638, in save_reduce
#     save(args)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 786, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 786, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 840, in _batch_appends
#     save(x)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 840, in _batch_appends
#     save(x)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 547, in save_function
#     return self.save_function_tuple(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\cloudpickle\cloudpickle.py", line 747, in save_function_tuple
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 815, in save_list
#     self.memoize(obj)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 460, in memoize
#     self.write(self.put(idx))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\pickle.py", line 464, in put
#     def put(self, idx):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 2039, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 3342, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 2042, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1385, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1288, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1150, in structured_traceback
#     formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
# TypeError: can only concatenate str (not "list") to str
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py", line 2039, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\am21907\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2038                         # in the engines. This should return a list of strings.
# -> 2039                         stb = value._render_traceback_()
#    2040                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py in run_code(self, code_obj, result, async_)
#    3340             if result is not None:
#    3341                 result.error_in_exec = sys.exc_info()[1]
# -> 3342             self.showtraceback(running_compiled_code=True)
#    3343         else:
#    3344             outflag = False
#
# ~\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2040                     except Exception:
#    2041                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2042                                             value, tb, tb_offset=tb_offset)
#    2043
#    2044                     self._showtraceback(etype, value, stb)
#
# ~\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1383         self.tb = tb
#    1384         return FormattedTB.structured_traceback(
# -> 1385             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1386
#    1387
#
# ~\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1286             # Verbose modes need a full traceback
#    1287             return VerboseTB.structured_traceback(
# -> 1288                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1289             )
#    1290         elif mode == 'Minimal':
#
# ~\AppData\Local\Continuum\anaconda3\envs\ATSC\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1148         exception = self.get_parts_of_chained_exception(evalue)
#    1149         if exception:
# -> 1150             formatted_exceptions += self.prepare_chained_exception_message(evalue.__cause__)
#    1151             etype, evalue, etb = exception
#    1152         else:
#
# TypeError: can only concatenate str (not "list") to str

# %%
test.review = test.review.swifter.allow_dask_on_strings().apply(lambda row: clean_up(row))

# %%
reviews = pd.concat([df.review,test.review])

# %%
from collections import Counter
cnt = Counter()
for text in tqdm(reviews.values):
    old_words = []
    for word in text.split():
        if word not in old_words:
            cnt[word] += 1
            old_words.append(word)

# %%
def remove_rare_freq_words(x):
    word_tokens = word_tokenize(x)
    x = []
    for w in word_tokens:
#         print("_*_"*100)
        if cnt[w] < high_pruner:
            x.append(w)
        elif cnt[w] > 20:
            x.append[w]
    x = " ".join(x)
    return x

# %%
high_pruner = reviews.shape[0]*0.65
reviews = reviews.progress_apply(lambda x : remove_rare_freq_words(x))
reviews[15]

# %%
clean_up("I happy had birthday too soon when where ok damn sorry after")

# %% [markdown]
# #1. Dict
# #2. Doc -> tokens token2id ##also remove duplicates
# #3. Doc -> token_count

# %%
texts = [[text for text in review.split()] for review in reviews]
dictionary = corpora.Dictionary(texts)
print(dictionary)

# %%
df.review = reviews[:break_point]
test.review = reviews[break_point:]

# %%
def prepare_df(df,col="review"):
    df = pd.DataFrame(reviews,columns=[col])
    df["bow"] = df[col].apply(lambda x : dictionary.doc2bow(x.split(),))
    df["tokens"] = df.bow.apply(lambda x: np.array([[i[0] for i in x]]))
    df["counts"] = df.bow.apply(lambda x: np.array([[i[1] for i in x]]))
    df.drop(['bow','review'],axis=1,inplace=True)
    return df

# %%
df = prepare_df(df)
df.head()

# %%
train , valid = df.iloc[:int(df.shape[0]*0.9),:],df.iloc[int(df.shape[0]*0.9):,:]
print(train.shape)
print(valid.shape)

# %%
test = prepare_df(test)
print(test.shape)
test.head()

# %%
test , test_1,test_2 = test.iloc[:int(test.shape[0]*0.5),:],test.iloc[int(test.shape[0]*0.5):int(test.shape[0]*0.75),:],test.iloc[int(test.shape[0]*0.75):,:]
print(test.shape)
print(test_1.shape)
print(test_2.shape)
# test_1_tokens = test['tokens_1']
# test_1_counts = test['counts_1']

# %%
reviews.to_csv("data/drug_review/preprocessed_reviews.csv",index=None,header=False)

# %%
df = pd.read_csv("data/drug_review/preprocessed_reviews.csv",header=None)
df

# %%
train

# %% [markdown]
# ## Saving The Files

# %%
path = "data/drug_review/"

# %%
# train.to_csv(path+"train.csv",index=None)
# test.to_csv(path+"test.csv",index=None)
# valid.to_csv(path+"valid.csv",index=None)
dictionary.save(path+"vocab.pkl")

# %%
def store_bow_files(df,filename):
    tokens = df.tokens.tolist()
    counts = df.counts.tolist()
    dict_ = {"tokens":tokens,"counts":counts}
    with open(path+filename+'.pkl', 'wb') as handle:
        pickle.dump(dict_, handle)

# %%
store_bow_files(train,"train_dict")
store_bow_files(test,"test_dict")
store_bow_files(test_1,"test_1_dict")
store_bow_files(test_2,"test_2_dict")
store_bow_files(valid,"valid_dict")

# %% [markdown]
# ## Validating The stored Files

# %%
with open(path + 'train_dict.pkl', 'rb') as handle:
    train = pickle.load(handle)
train

# %%
with open(path + 'test_dict.pkl', 'rb') as handle:
    test = pickle.load(handle)
test

# %%
with open(path + 'valid_dict.pkl', 'rb') as handle:
    valid = pickle.load(handle)
valid
